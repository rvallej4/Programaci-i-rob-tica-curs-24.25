# %%
import pandas as pd
noosa = pd.read_csv("/content/noosa.csv") #cal guardar els csv en UTF-8
noosa

#canviem la columna State/Organization per a cridar-la correctament
# Out:
#    International Designator National Designator  \
# 0                 2019-097A                 NaN
# 1               [2019-096C]       3538-2019-021
# 2               [2019-096B]       3537-2019-021
# 3               [2019-096A]       3536-2019-021
# 4               [2019-096E]                 NaN
# 5               [2019-095A]       3535-2019-020
# 6               [2019-093B]                 NaN
# 7                 2019-093C                 NaN
# 8                 2019-093H                 NaN
# 9                 2019-093G                 NaN
# 10                2019-093F                 NaN
# 11              [2019-093*]                 NaN
# 12                2019-093A                 NaN
# 13                2019-093D                 NaN
# 14              [2019-093E]                 NaN
# 15                2019-094A                 NaN
# 16                2019-092D                 NaN
# 17                2019-092B                 NaN
# ...

# %% [markdown]
# - Calculeu quants objectes en òrbita són de: «Russian Federation», «China», «USA» i «ESA»
# - Què és la ESA? Responeu-ho al mig del codi, amb una anotació.
# - Calculeu quants satèl·lits estan en òrbita i quants ja no ho estan.
# - Quan va deixar de ser funcional aquest satèl·lit? (2019-092F) → status = #decayed

# %%
n2 = noosa["State"].str.contains("Russian Federation") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 8

# %%
n2 = noosa["State"].str.contains("China") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 17

# %%
n2 = noosa["State"].str.contains("USA") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 17

# %%
n2 = noosa["State"].str.contains("ESA") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 2

# %%
n2 = noosa["State"].str.contains("ESA") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 2

# %%
n2 = noosa["Status"].str.contains("in orbit") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 32

# %%
n2 = noosa["Status"].str.contains("decayed")#Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 22

# %%
noosa2 = noosa.loc[noosa['International Designator'].str.contains('2019-092F')] #localitzar linia del satèl·lit
noosa2["Date of Decay or Change"] #mostrar columna del decay
# Out:
# 19    [2024-05-22]
# Name: Date of Decay or Change, dtype: object
